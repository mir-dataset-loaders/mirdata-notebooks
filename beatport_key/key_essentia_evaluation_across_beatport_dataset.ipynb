# %% [markdown]
# # Evaluating essentia key extractor over Beatport EDM datasets.
#
# In this colabolatory notebook we are going going to show how to load Beatport EDM tempo dataset. And we are going to evalute the essentia key extractor `KeyExtractor(...)`.

# %% [markdown]
# ### Importing mir_eval

# %%
# !pip install git+https://github.com/PRamoneda/mir_eval.git@Pedro/only_key
import mir_eval
# Out:
# Collecting git+https://github.com/PRamoneda/mir_eval.git@Pedro/only_key
#   Cloning https://github.com/PRamoneda/mir_eval.git (to revision Pedro/only_key) to /tmp/pip-req-build-lf8j6jv7
#   Running command git clone -q https://github.com/PRamoneda/mir_eval.git /tmp/pip-req-build-lf8j6jv7
#   Running command git checkout -b Pedro/only_key --track origin/Pedro/only_key
#   Switched to a new branch 'Pedro/only_key'
#   Branch 'Pedro/only_key' set up to track remote branch 'Pedro/only_key' from 'origin'.
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from mir-eval==0.6) (1.18.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from mir-eval==0.6) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from mir-eval==0.6) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from mir-eval==0.6) (1.15.0)
# Building wheels for collected packages: mir-eval
#   Building wheel for mir-eval (setup.py) ... done
#   Created wheel for mir-eval: filename=mir_eval-0.6-cp36-none-any.whl size=97582 sha256=b0f706dba94042c2dcf61815832da15f52a2d543077e2428d956e79764207262
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cdic8l0g/wheels/0e/26/dd/6dc42f9f128108b06932044ac1f78f18635e85593f59bfefc5
# Successfully built mir-eval
# Installing collected packages: mir-eval
# Successfully installed mir-eval-0.6

# %% [markdown]
# ### Importing mirdata and loading Beatport key dataset

# %%
# !pip install git+https://github.com/mir-dataset-loaders/mirdata.git@Pedro/bug/beatport_key
# Out:
# Collecting git+https://github.com/mir-dataset-loaders/mirdata.git@Pedro/bug/beatport_key
#   Cloning https://github.com/mir-dataset-loaders/mirdata.git (to revision Pedro/bug/beatport_key) to /tmp/pip-req-build-9xdyjapg
#   Running command git clone -q https://github.com/mir-dataset-loaders/mirdata.git /tmp/pip-req-build-9xdyjapg
#   Running command git checkout -b Pedro/bug/beatport_key --track origin/Pedro/bug/beatport_key
#   Switched to a new branch 'Pedro/bug/beatport_key'
#   Branch 'Pedro/bug/beatport_key' set up to track remote branch 'Pedro/bug/beatport_key' from 'origin'.
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from mirdata==0.2.2) (4.41.1)
# Collecting librosa>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/26/4d/c22d8ca74ca2c13cd4ac430fa353954886104321877b65fa871939e78591/librosa-0.8.0.tar.gz (183kB)
#      |████████████████████████████████| 184kB 2.6MB/s
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from mirdata==0.2.2) (1.18.5)
# Collecting jams
#   Downloading https://files.pythonhosted.org/packages/cc/1a/761a500a9512937931e325b8950195f17e5ba991c92d38d2079a2d8c5590/jams-0.3.4.tar.gz (51kB)
#      |████████████████████████████████| 61kB 3.8MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from mirdata==0.2.2) (2.23.0)
# Collecting pretty_midi>=0.2.8
#   Downloading https://files.pythonhosted.org/packages/bc/8e/63c6e39a7a64623a9cd6aec530070c70827f6f8f40deec938f323d7b1e15/pretty_midi-0.2.9.tar.gz (5.6MB)
#      |████████████████████████████████| 5.6MB 4.8MB/s
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa>=0.8.0->mirdata==0.2.2) (2.1.9)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa>=0.8.0->mirdata==0.2.2) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from librosa>=0.8.0->mirdata==0.2.2) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.6/dist-packages (from librosa>=0.8.0->mirdata==0.2.2) (0.17.0)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa>=0.8.0->mirdata==0.2.2) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from librosa>=0.8.0->mirdata==0.2.2) (0.2.2)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.6/dist-packages (from librosa>=0.8.0->mirdata==0.2.2) (0.48.0)
# Collecting soundfile>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/eb/f2/3cbbbf3b96fb9fa91582c438b574cff3f45b29c772f94c400e2c99ef5db9/SoundFile-0.10.3.post1-py2.py3-none-any.whl
# Collecting pooch>=1.0
#   Downloading https://files.pythonhosted.org/packages/ce/11/d7a1dc8173a4085759710e69aae6e070d0d432db84013c7c343e4e522b76/pooch-1.2.0-py3-none-any.whl (47kB)
#      |████████████████████████████████| 51kB 6.7MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from jams->mirdata==0.2.2) (1.1.3)
# Requirement already satisfied: sortedcontainers>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from jams->mirdata==0.2.2) (2.2.2)
# Collecting jsonschema>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 7.4MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from jams->mirdata==0.2.2) (1.15.0)
# Requirement already satisfied: mir_eval>=0.5 in /usr/local/lib/python3.6/dist-packages (from jams->mirdata==0.2.2) (0.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->mirdata==0.2.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->mirdata==0.2.2) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->mirdata==0.2.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->mirdata==0.2.2) (2020.6.20)
# Collecting mido>=1.1.16
#   Downloading https://files.pythonhosted.org/packages/20/0a/81beb587b1ae832ea6a1901dc7c6faa380e8dd154e0a862f0a9f3d2afab9/mido-1.2.9-py2.py3-none-any.whl (52kB)
#      |████████████████████████████████| 61kB 5.5MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba>=0.43.0->librosa>=0.8.0->mirdata==0.2.2) (50.3.2)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.43.0->librosa>=0.8.0->mirdata==0.2.2) (0.31.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile>=0.9.0->librosa>=0.8.0->mirdata==0.2.2) (1.14.3)
# Collecting appdirs
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from pooch>=1.0->librosa>=0.8.0->mirdata==0.2.2) (20.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->jams->mirdata==0.2.2) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->jams->mirdata==0.2.2) (2018.9)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.0->jams->mirdata==0.2.2) (2.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.0->jams->mirdata==0.2.2) (20.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from jsonschema>=3.0.0->jams->mirdata==0.2.2) (0.17.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from mir_eval>=0.5->jams->mirdata==0.2.2) (0.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile>=0.9.0->librosa>=0.8.0->mirdata==0.2.2) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->pooch>=1.0->librosa>=0.8.0->mirdata==0.2.2) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->jsonschema>=3.0.0->jams->mirdata==0.2.2) (3.3.1)
# Building wheels for collected packages: mirdata, librosa, jams, pretty-midi
#   Building wheel for mirdata (setup.py) ... done
#   Created wheel for mirdata: filename=mirdata-0.2.2-cp36-none-any.whl size=2586562 sha256=703a406760056814db52d37989ff7eb10b686914f6f3a839208323f63ce71a57
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m7batxhc/wheels/5d/ed/a8/b38190bc3cfa7341dce2d121fd840cf9a6d6234291327d2ea6
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.8.0-cp36-none-any.whl size=201376 sha256=5ffaa0e4a6efedd9e48bda81b251598340feb28df8156f949991500d16f7866a
#   Stored in directory: /root/.cache/pip/wheels/ee/10/1e/382bb4369e189938d5c02e06d10c651817da8d485bfd1647c9
#   Building wheel for jams (setup.py) ... done
#   Created wheel for jams: filename=jams-0.3.4-cp36-none-any.whl size=64925 sha256=bf827a030280e839b80b5c5c1c1027634e3ca994c3b06c61a3ea07c2bc317608
#   Stored in directory: /root/.cache/pip/wheels/2b/b8/c7/092096a3af0eb864cca4e79a44bc883dee5b9767da2c6f8ab3
#   Building wheel for pretty-midi (setup.py) ... done
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-cp36-none-any.whl size=5591954 sha256=2f7a9042245d983c4c3a04ebea1eaad840314e4e3241011c656beae6cb09012f
#   Stored in directory: /root/.cache/pip/wheels/4c/a1/c6/b5697841db1112c6e5866d75a6b6bf1bef73b874782556ba66
# Successfully built mirdata librosa jams pretty-midi
# ERROR: nbclient 0.5.1 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# Installing collected packages: soundfile, appdirs, pooch, librosa, jsonschema, jams, mido, pretty-midi, mirdata
#   Found existing installation: librosa 0.6.3
#     Uninstalling librosa-0.6.3:
#       Successfully uninstalled librosa-0.6.3
#   Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
# Successfully installed appdirs-1.4.4 jams-0.3.4 jsonschema-3.2.0 librosa-0.8.0 mido-1.2.9 mirdata-0.2.2 pooch-1.2.0 pretty-midi-0.2.9 soundfile-0.10.3.post1

# %%
import mirdata.beatport_key as bp_key

bp_key.download()
# Out:
# 0.00B [00:00, ?B/s]
# Starting to download ['keys', 'metadata', 'audio'] to folder /root/mir_datasets/beatport_key
# > downloading keys
# 376kB [00:02, 145kB/s]
# 0.00B [00:00, ?B/s]
# > downloading metadata
# 904kB [00:01, 556kB/s]
# 0.00B [00:00, ?B/s]
# > downloading audio
# 1.98GB [04:32, 7.82MB/s]

# %%
bp_key.validate()
# Out:
# Success: the dataset is complete and all files are valid.
# --------------------
# ({}, {})

# %% [markdown]
# ### Importing essentia

# %%
# !pip install essentia
# Out:
# Requirement already satisfied: essentia in /usr/local/lib/python3.6/dist-packages (2.1b6.dev234)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from essentia) (3.13)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from essentia) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from essentia) (1.15.0)

# %%
from essentia.standard import KeyExtractor, MonoLoader

# %%
results = []
key_extractor = KeyExtractor()
for k, v in bp_key.load().items():
  # compute estimated key
  loader = MonoLoader(filename=v.audio_path)
  audio = loader()
  estimated_key = key_extractor(audio)
  estimated_key = estimated_key[0] + ' ' + estimated_key[1]
  # copmpute the best score of the possible keys
  score = []
  for r_key in v.key:
    if r_key.split(' ')[0].lower() == 'x': # if is ambiguous
        reference_key = 'X'
    else:
        reference_key = r_key.split(' ')[0] + ' ' + r_key.split(' ')[1]
    # _ and ^ not supported by mir_eval and essentia
    if not '^' in reference_key and not '_' in reference_key:
      score.append(mir_eval.key.weighted_score(reference_key, estimated_key))
  # add to results and print
  if not '^' in reference_key and not '_' in reference_key:
    results.append(str(max(score)))
  print("Reference key:", v.key, "Estimated key:", estimated_key, score)
# Out:
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['G minor', 'Bb major'] Estimated key: D minor [0.5, 0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['B minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['B major phrygian-major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor', 'C# major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['B major', 'B minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['G# minor', 'B major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['Ab major', 'F minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['Bb other'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['B other'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D major phrygian-major'] Estimated key: D minor [0.2]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['C# major', 'A# minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F minor', 'F major'] Estimated key: D minor [0.0, 0.3]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F minor', 'F major'] Estimated key: D minor [0.0, 0.3]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor', 'F major'] Estimated key: D minor [1.0, 0.3]
# Reference key: ['D minor', 'F major'] Estimated key: D minor [1.0, 0.3]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major mixolydian-b6'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['A other', 'Bb other'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['E major', 'E minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G major', 'G minor'] Estimated key: D minor [0.0, 0.5]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major mixolydian'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C major mixolydian'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F other', 'E other'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor', 'F major'] Estimated key: D minor [1.0, 0.3]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['Bb other', 'A minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['A minor', 'A major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['A minor', 'A major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['A# major mixolydian'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F minor', 'Ab major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['E minor dorian'] Estimated key: D minor [0.0]
# Reference key: ['A major mixolydian'] Estimated key: D minor [0.0]
# Reference key: ['A minor', 'A major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor', 'A major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['E minor dorian'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['F major', 'D minor'] Estimated key: D minor [0.3, 1.0]
# Reference key: ['F major', 'D minor'] Estimated key: D minor [0.3, 1.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor', 'B minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['G# major', 'G# minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G# major', 'G# minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['A# minor', 'A# major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F major lydian'] Estimated key: D minor [0.3]
# Reference key: ['A# major', 'A# minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['G major', 'G minor'] Estimated key: D minor [0.0, 0.5]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A# major', 'A# minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor', 'C major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major', 'D# minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['F major', 'F minor'] Estimated key: D minor [0.3, 0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['Bb major', 'F minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G# major', 'D# major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['D# other'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C major', 'G major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['A major', 'A minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G minor', 'G major'] Estimated key: D minor [0.5, 0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['G major', 'E minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['C major', 'A minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['D major mixolydian'] Estimated key: D minor [0.2]
# Reference key: ['A major', 'F# minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['x'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['F minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['D major mixolydian'] Estimated key: D minor [0.2]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['G minor', 'G major'] Estimated key: D minor [0.5, 0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['A minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['C minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major mixolydian'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F major', 'G minor'] Estimated key: D minor [0.3, 0.5]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor', 'Ab major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['F other'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['A# major', 'D minor'] Estimated key: D minor [0.0, 1.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['A# minor', 'A# major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['B other'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['C# major mixolydian'] Estimated key: D minor [0.0]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['E major', 'A major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['x'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['F major', 'D minor'] Estimated key: D minor [0.3, 1.0]
# Reference key: ['C# minor', 'C# major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['A minor phrygian-major', 'A major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C# other'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['E minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C major', 'A minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['A major', 'A minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['F major'] Estimated key: D minor [0.3]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor', 'F major'] Estimated key: D minor [0.0, 0.3]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F major', 'D minor'] Estimated key: D minor [0.3, 1.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor', 'D minor'] Estimated key: D minor [0.0, 1.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['F major', 'D minor'] Estimated key: D minor [0.3, 1.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# ...
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['A major', 'A minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['F major', 'F minor'] Estimated key: D minor [0.3, 0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['A# major mixolydian'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor', 'C# major '] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C# major '] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C other'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['F minor phrygian'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['B other'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['Bb major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G other', 'C# other'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C# major '] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['G#_ minor', 'A^ minor'] Estimated key: D minor []
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['B major'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['A minor', 'C major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor', 'E major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['E major', 'C# minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C major'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['Eb major', 'C minor'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['D# major'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G minor', 'G major'] Estimated key: D minor [0.5, 0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['F# major'] Estimated key: D minor [0.0]
# Reference key: ['F# minor'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['A# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['D major'] Estimated key: D minor [0.2]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['A minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['D# minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['B minor'] Estimated key: D minor [0.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['D minor'] Estimated key: D minor [1.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['E major'] Estimated key: D minor [0.0]
# Reference key: ['G# major'] Estimated key: D minor [0.0]
# Reference key: ['F# minor', 'F# major'] Estimated key: D minor [0.0, 0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['G minor'] Estimated key: D minor [0.5]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['G major'] Estimated key: D minor [0.0]
# Reference key: ['E minor'] Estimated key: D minor [0.0]
# Reference key: ['C# minor'] Estimated key: D minor [0.0]
# Reference key: ['A# minor'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['F minor'] Estimated key: D minor [0.0]
# Reference key: ['X'] Estimated key: D minor [0.0]
# Reference key: ['C# major'] Estimated key: D minor [0.0]
# Reference key: ['C minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]
# Reference key: ['G# minor'] Estimated key: D minor [0.0]

# %%
from collections import Counter
num_tracks = len(results)
bp_key_results = Counter(results)
print(num_tracks, bp_key_results)
# Out:
# 1484 Counter({'0.0': 1230, '1.0': 92, '0.5': 81, '0.2': 49, '0.3': 32})

# %%
print("RESULTS:")
print("Same key: " + str(bp_key_results['1.0']/num_tracks*100) + "%")
print("Estimated key is a perfect fifth above reference key: " + str(bp_key_results['0.5']/num_tracks*100) + "%")
print("Relative major/minor: " + str(bp_key_results['0.3']/num_tracks*100) + "%")
print("Parallel major/minor: " + str(bp_key_results['0.2']/num_tracks*100) + "%")
print("Other: " + str(bp_key_results['0.0']/num_tracks*100) + "%")
# Out:
# RESULTS:
# Same key: 6.199460916442049%
# Estimated key is a perfect fifth above reference key: 5.45822102425876%
# Relative major/minor: 2.15633423180593%
# Parallel major/minor: 3.30188679245283%
# Other: 82.88409703504043%
